# %% [markdown]
# ## What is the population structure for each region of London? (From 32 London Borough data)
# ![image.png](attachment:image.png)
#
# #### Data last updated 28 May 2020

# %%
"""
from sqlalchemy import create_engine
import pymysql
import pandas as pd

sqlEngine       = create_engine('mysql+pymysql://root:@127.0.0.1', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

frame           = pd.read_sql("select * from London_Sub_Regions", dbConnection);


pd.set_option('display.expand_frame_repr', False)

print(frame)

dbConnection.close()
"""

# %%
import mysql.connector
import pandas as pd

my_conn = mysql.connector.connect(
      host="localhost",
      user="root",
      passwd="Stop@1command",
      database="London_Sub_Regions"
    )

# %%
londonEast_df = pd.read_sql("SELECT * FROM East",my_conn)

londonWest_df = pd.read_sql("SELECT * FROM West",my_conn)

londonSouth_df = pd.read_sql("SELECT * FROM South",my_conn)

londonNorth_df = pd.read_sql("SELECT * FROM North",my_conn)

londonCentral_df = pd.read_sql("SELECT * FROM Central",my_conn)
# Out:
# C:\Users\y_har\AppData\Local\Temp\ipykernel_18096\2873133183.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   londonEast_df = pd.read_sql("SELECT * FROM East",my_conn)
# C:\Users\y_har\AppData\Local\Temp\ipykernel_18096\2873133183.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   londonWest_df = pd.read_sql("SELECT * FROM West",my_conn)
# C:\Users\y_har\AppData\Local\Temp\ipykernel_18096\2873133183.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   londonSouth_df = pd.read_sql("SELECT * FROM South",my_conn)
# ...

# %%
londonNorth_df
# Out:
#    ID   Borough           Local_Authority  Area_sqm  Population_est
# 0   1  Haringey  Haringey Borough Council     11.42          268647
# 1   2   Enfield   Enfield Borough Council     31.74          333794
# 2   3    Barnet    Barnet Borough Council     33.49          395896

# %%
londonEast_df
# Out:
#    ID             Borough                     Local_Authority  Area_sqm  \
# 0   7       Tower Hamlets       Tower Hamlets Borough Council      7.63
# 1   8             Hackney             Hackney Borough Council      7.36
# 2  21           Greenwich           Greenwich Borough Council     18.28
# 3  22              Bexley              Bexley Borough Council     23.38
# 4  23            Havering            Havering Borough Council     43.35
# 5  24  Barking & Dagenham  Barking & Dagenham Borough Council     13.93
# 6  25           Redbridge           Redbridge Borough Council     21.78
# 7  26              Newham             Newham Borough Council      13.98
# 8  27      Waltham Forest      Waltham Forest Borough Council     14.99
#
#    Population_est
# 0          324745
# 1          281120
# 2          287942
# 3          248287
# 4          259552
# 5          212906
# 6          305222
# 7          353134
# 8          276983

# %%
londonSouth_df
# Out:
#    ID               Borough             Local_Authority  Area_sqm  \
# 0   4            Wandsworth  Wandsworth Borough Council     13.23
# 1   6             Southwark   Southwark Borough Council     11.14
# 2  15  Kingston upon Thames      Bexley Borough Council     14.38
# 3  16                Merton      Merton Borough Council     14.52
# 4  17                Sutton      Sutton Borough Council     16.93
# 5  18               Croydon     Croydon Borough Council     33.41
# 6  19               Bromley    Bromley Borough Council      57.97
# 7  20              Lewisham    Lewisham Borough Council     13.57
#
#    Population_est
# 0          329677
# 1          318830
# 2          177507
# 3          206548
# 4          206349
# 5          386710
# 6          332336
# 7          305842

# %%
londonWest_df
# Out:
#    ID               Borough                       Local_Authority  Area_sqm  \
# 0   3  Hammersmith & Fulham  Hammersmith & Fulham Borough Council      6.33
# 1  11                 Brent                 Brent Borough Council     16.70
# 2  12                Ealing                Ealing Borough Council     21.44
# 3  12              Hounslow              Hounslow Borough Council     21.61
# 4  12  Richmond upon Thames  Richmond upon Thames Borough Council     22.17
# 5  31                Harrow               Harrow  Borough Council     19.49
# 6  32            Hillingdon           Hillingdon  Borough Council     44.67
#
#    Population_est
# 0          185143
# 1          329771
# 2          341806
# 3          271523
# 4          198019
# 5          251160
# 6          306870

# %%
londonCentral_df
# Out:
#    ID               Borough                       Local_Authority  Area_sqm  \
# 0   1           Westminster              Westminster City Council      8.29
# 1   2  Kensington & Chelsea  Kensington & Chelsea Borough Council      4.68
# 2   3  Hammersmith & Fulham  Hammersmith & Fulham Borough Council      6.33
# 3   9             Islington             Islington Borough Council      5.74
# 4  10                Camden                Camden Borough Council      8.40
#
#    Population_est
# 0          261317
# 1          156129
# 2          185143
# 3          242467
# 4          270029

# %%
import pandas as pd

deaths_df = pd.read_excel("C:/Users/y_har/Desktop/CFG Degree Data Course Material/Data/Project/Underlying_data.xlsx", 
            sheet_name= "1 deaths")
deaths_df
# Out:
#       MSOA11CD                 MSOA11NM        local_authority  \
# 0    E02000001        City of London 001        City of London
# 1    E02000002  Barking and Dagenham 001  Barking and Dagenham
# 2    E02000003  Barking and Dagenham 002  Barking and Dagenham
# 3    E02000004  Barking and Dagenham 003  Barking and Dagenham
# 4    E02000005  Barking and Dagenham 004  Barking and Dagenham
# ..         ...                       ...                   ...
# 978  E02006927             Greenwich 034             Greenwich
# 979  E02006928             Greenwich 035             Greenwich
# 980  E02006929             Greenwich 036             Greenwich
# 981  E02006930             Greenwich 037             Greenwich
# 982  E02006931             Greenwich 038             Greenwich
#
#      covid_19_deaths  covid_19_deaths_per_thousand
# 0                  3                      0.344590
# 1                  2                      0.259067
# 2                  3                      0.271469
# ...

# %%
import pandas as pd

population_df = pd.read_excel("C:/Users/y_har/Desktop/CFG Degree Data Course Material/Data/Project/Underlying_data.xlsx", 
                sheet_name = '2 population')
population_df
# Out:
#       MSOA11CD                  MSOA11NM       Local authority  \
# 0    E02000001        City of London 001        City of London
# 1    E02000002  Barking and Dagenham 001  Barking and Dagenham
# 2    E02000003  Barking and Dagenham 002  Barking and Dagenham
# 3    E02000004  Barking and Dagenham 003  Barking and Dagenham
# 4    E02000005  Barking and Dagenham 004  Barking and Dagenham
# ..         ...                       ...                   ...
# 978  E02006927             Greenwich 034             Greenwich
# 979  E02006928             Greenwich 035             Greenwich
# 980  E02006929             Greenwich 036             Greenwich
# 981  E02006930             Greenwich 037             Greenwich
# 982  E02006931             Greenwich 038             Greenwich
#
#      total_population_mid_2018  over_70_prop
# 0                         8706      0.123593
# 1                         7720      0.103886
# 2                        11051      0.085965
# ...

# %%
ethnicGroup_df = pd.read_excel("C:/Users/y_har/Desktop/CFG Degree Data Course Material/Data/Project/Underlying_data.xlsx", 
                sheet_name= "4 ethnic_group")
ethnicGroup_df
# Out:
#       MSOA11CD                  MSOA11NM       Local Authority  all_bame_prop  \
# 0    E02000001        City of London 001        City of London       0.213695
# 1    E02000002  Barking and Dagenham 001  Barking and Dagenham       0.350111
# 2    E02000003  Barking and Dagenham 002  Barking and Dagenham       0.453858
# 3    E02000004  Barking and Dagenham 003  Barking and Dagenham       0.190230
# 4    E02000005  Barking and Dagenham 004  Barking and Dagenham       0.337304
# ..         ...                       ...                   ...            ...
# 978  E02006927             Greenwich 034             Greenwich       0.290559
# 979  E02006928             Greenwich 035             Greenwich       0.414249
# 980  E02006929             Greenwich 036             Greenwich       0.379706
# 981  E02006930             Greenwich 037             Greenwich       0.220850
# 982  E02006931             Greenwich 038             Greenwich       0.267472
#
# ...

# %%
ethnicBoroughs_df = pd.read_excel("C:/Users/y_har/Desktop/CFG Degree Data Course Material/Data/Project/ethnic-groups-by-borough.xls", 
                sheet_name= "2019")
ethnicBoroughs_df
# Out:
#          Code                      Area    Number Unnamed: 3 Unnamed: 4  \
# 0         NaN                       NaN     White      Asian      Black
# 1         NaN                       NaN       NaN        NaN        NaN
# 2   E09000001            City of London         -          -          -
# 3   E09000002      Barking and Dagenham     99000      55000      51000
# 4   E09000003                    Barnet    255000      79000      28000
# 5   E09000004                    Bexley    188000      20000      28000
# 6   E09000005                     Brent    117000     138000      40000
# 7   E09000006                   Bromley    264000      25000      23000
# 8   E09000007                    Camden    155000      34000      29000
# 9   E09000008                   Croydon    224000      78000      61000
# 10  E09000009                    Ealing    163000      91000      29000
# 11  E09000010                   Enfield    218000      44000      58000
# ...

# %%
ethnicBoroughs1_df = pd.read_excel("C:/Users/y_har/Desktop/CFG Degree Data Course Material/Data/Project/ethnic-groups-by-borough.xls", 
                sheet_name= "2020")
ethnicBoroughs1_df
# Out:
#          Code                      Area    Number Unnamed: 3 Unnamed: 4  \
# 0         NaN                       NaN     White      Asian      Black
# 1         NaN                       NaN       NaN        NaN        NaN
# 2   E09000001            City of London         -          -          -
# 3   E09000002      Barking and Dagenham     99000      55000      51000
# 4   E09000003                    Barnet    255000      79000      28000
# 5   E09000004                    Bexley    188000      20000      28000
# 6   E09000005                     Brent    117000     138000      40000
# 7   E09000006                   Bromley    264000      25000      23000
# 8   E09000007                    Camden    155000      34000      29000
# 9   E09000008                   Croydon    224000      78000      61000
# 10  E09000009                    Ealing    163000      91000      29000
# 11  E09000010                   Enfield    218000      44000      58000
# ...

# %%
londonDeaths_df = pd.read_csv("C:/Users/y_har/Desktop/CFG Degree Data Course Material/Data/Project/phe_deaths_london_boroughs.csv")
londonDeaths_df
# Out:
#                   area_name  area_code        date  new_deaths  total_deaths
# 0      Barking and Dagenham  E09000002  2020-03-09           0             0
# 1                    Barnet  E09000003  2020-03-09           0             0
# 2                    Bexley  E09000004  2020-03-09           0             0
# 3                     Brent  E09000005  2020-03-09           0             0
# 4                   Bromley  E09000006  2020-03-09           0             0
# ...                     ...        ...         ...         ...           ...
# 30363                Sutton  E09000029  2022-10-13           0           598
# 30364         Tower Hamlets  E09000030  2022-10-13           0           501
# 30365        Waltham Forest  E09000031  2022-10-13           0           654
# 30366            Wandsworth  E09000032  2022-10-13           0           633
# 30367           Westminster  E09000033  2022-10-13           0           423
#
# [30368 rows x 5 columns]

# %%
londonDeathsAge_df = pd.read_csv("C:/Users/y_har/Desktop/CFG Degree Data Course Material/Data/Project/phe_deaths_age_london.csv")
londonDeathsAge_df
# Out:
#       area_name  area_code        date  deaths  rolling_sum  rolling_rate  \
# 0        London  E12000007  2022-10-01       0            0           0.0
# 1        London  E12000007  2022-10-01       0            0           0.0
# 2        London  E12000007  2022-10-01       0            0           0.0
# 3        London  E12000007  2022-10-01       0            0           0.0
# 4        London  E12000007  2022-10-01       0            0           0.0
# ...         ...        ...         ...     ...          ...           ...
# 17798    London  E12000007  2020-03-09       1            0           0.0
# 17799    London  E12000007  2020-03-09       0            0           0.0
# 17800    London  E12000007  2020-03-09       0            0           0.0
# 17801    London  E12000007  2020-03-09       0            0           0.0
# 17802    London  E12000007  2020-03-09       0            0           0.0
#
#             age_band  age_lower  age_higher  population
# ...

# %%
BoroughVaccines_df = pd.read_csv("C:/Users/y_har/Desktop/CFG Degree Data Course Material/Data/Project/phe_vaccines_age_london_boroughs.csv")
BoroughVaccines_df
# Out:
#                     area_name  area_code        date             dose  \
# 0        Barking and Dagenham  E09000002  2020-12-08         1st dose
# 1        Barking and Dagenham  E09000002  2020-12-08         1st dose
# 2        Barking and Dagenham  E09000002  2020-12-08         1st dose
# 3        Barking and Dagenham  E09000002  2020-12-08         1st dose
# 4        Barking and Dagenham  E09000002  2020-12-08         1st dose
# ...                       ...        ...         ...              ...
# 1941025           Westminster  E09000033  2022-10-12  spring22by dose
# 1941026           Westminster  E09000033  2022-10-12  spring22by dose
# 1941027           Westminster  E09000033  2022-10-12  spring22by dose
# 1941028           Westminster  E09000033  2022-10-12  spring22by dose
# 1941029           Westminster  E09000033  2022-10-12  spring22by dose
#
#               age_band  age_higher  age_lower  cum_doses  new_doses  \
# ...
